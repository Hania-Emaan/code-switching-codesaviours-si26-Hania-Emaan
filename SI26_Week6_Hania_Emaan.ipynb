# %% [markdown]
# <a href="https://colab.research.google.com/github/Hania-Emaan/code-switching-codesaviours-si26-Hania-Emaan/blob/main/SI26_Week6_Hania_Emaan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd


# 2. Create a folder in your Drive to keep it safe permanently
drive_folder = '/content/drive/MyDrive/CodeSaviours_Project2'
os.makedirs(drive_folder, exist_ok=True)

# 3. Your dataset (exact same format as mentor's code)
data = [
    # 1-10
    {
        'sentence': 'Aaj ka din bohot busy tha',
        'words': ['Aaj', 'ka', 'din', 'bohot', 'busy', 'tha'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'ENG', 'URD']
    },
    {
        'sentence': 'Yaar seriously I can not even right now',
        'words': ['Yaar', 'seriously', 'I', 'can', 'not', 'even', 'right', 'now'],
        'labels': ['URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Bhai kal mera presentation hai still not prepared at all',
        'words': ['Bhai', 'kal', 'mera', 'presentation', 'hai', 'still', 'not', 'prepared', 'at', 'all'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Khana kha liya I was literally waiting for you',
        'words': ['Khana', 'kha', 'liya', 'I', 'was', 'literally', 'waiting', 'for', 'you'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Mujhe samajh nahi aa raha why this code is giving error',
        'words': ['Mujhe', 'samajh', 'nahi', 'aa', 'raha', 'why', 'this', 'code', 'is', 'giving', 'error'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Mera assignment complete ho gaya hai I will submit it tomorrow',
        'words': ['Mera', 'assignment', 'complete', 'ho', 'gaya', 'hai', 'I', 'will', 'submit', 'it', 'tomorrow'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Kal subah early morning class hai so I need to sleep early',
        'words': ['Kal', 'subah', 'early', 'morning', 'class', 'hai', 'so', 'I', 'need', 'to', 'sleep', 'early'],
        'labels': ['URD', 'URD', 'ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Project deadline is approaching fast aur humne abhi tak start bhi nahi kiya',
        'words': ['Project', 'deadline', 'is', 'approaching', 'fast', 'aur', 'humne', 'abhi', 'tak', 'start', 'bhi', 'nahi', 'kiya'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Professor is very strict late submission accept nahi karenge',
        'words': ['Professor', 'is', 'very', 'strict', 'late', 'submission', 'accept', 'nahi', 'karenge'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'URD']
    },
    {
        'sentence': 'Group project mein koi kaam nahi kar raha I have to do everything myself',
        'words': ['Group', 'project', 'mein', 'koi', 'kaam', 'nahi', 'kar', 'raha', 'I', 'have', 'to', 'do', 'everything', 'myself'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 11-20
    {
        'sentence': 'Mera laptop crash ho gaya lost all my unsaved files',
        'words': ['Mera', 'laptop', 'crash', 'ho', 'gaya', 'lost', 'all', 'my', 'unsaved', 'files'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Library mein bohot noise hai I cannot concentrate here',
        'words': ['Library', 'mein', 'bohot', 'noise', 'hai', 'I', 'cannot', 'concentrate', 'here'],
        'labels': ['ENG', 'URD', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Bhai notes share kar do I missed today lecture',
        'words': ['Bhai', 'notes', 'share', 'kar', 'do', 'I', 'missed', 'today', 'lecture'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Exam pass ho gaya hard work finally paid off',
        'words': ['Exam', 'pass', 'ho', 'gaya', 'hard', 'work', 'finally', 'paid', 'off'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Office meeting was so boring poora time neend aati rahi',
        'words': ['Office', 'meeting', 'was', 'so', 'boring', 'poora', 'time', 'neend', 'aati', 'rahi'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'I need a long vacation bohot burnout feel ho raha hai',
        'words': ['I', 'need', 'a', 'long', 'vacation', 'bohot', 'burnout', 'feel', 'ho', 'raha', 'hai'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Salary credit ho gayi time to pay all the pending bills',
        'words': ['Salary', 'credit', 'ho', 'gayi', 'time', 'to', 'pay', 'all', 'the', 'pending', 'bills'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Resume update kar liya hai now applying for remote jobs',
        'words': ['Resume', 'update', 'kar', 'liya', 'hai', 'now', 'applying', 'for', 'remote', 'jobs'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Interview schedule ho gaya hai for next Monday',
        'words': ['Interview', 'schedule', 'ho', 'gaya', 'hai', 'for', 'next', 'Monday'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Manager ne feedback diya hai need to make some quick revisions',
        'words': ['Manager', 'ne', 'feedback', 'diya', 'hai', 'need', 'to', 'make', 'some', 'quick', 'revisions'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 21-30
    {
        'sentence': 'Chai peene chalte hain I really need a short break',
        'words': ['Chai', 'peene', 'chalte', 'hain', 'I', 'really', 'need', 'a', 'short', 'break'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Weather is so nice today baahir ghoomne chalte hain',
        'words': ['Weather', 'is', 'so', 'nice', 'today', 'baahir', 'ghoomne', 'chalte', 'hain'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Bohot zor ki bhook lag rahi hai let us order some food',
        'words': ['Bohot', 'zor', 'ki', 'bhook', 'lag', 'rahi', 'hai', 'let', 'us', 'order', 'some', 'food'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Traffic bohot heavy tha I got stuck for 2 hours',
        'words': ['Traffic', 'bohot', 'heavy', 'tha', 'I', 'got', 'stuck', 'for', '2', 'hours'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'MIX', 'ENG']
    },
    {
        'sentence': 'Ghar pohench kar call karta hoon currently driving',
        'words': ['Ghar', 'pohench', 'kar', 'call', 'karta', 'hoon', 'currently', 'driving'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'URD', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': 'Electricity chali gayi hai generator bhi work nahi kar raha',
        'words': ['Electricity', 'chali', 'gayi', 'hai', 'generator', 'bhi', 'work', 'nahi', 'kar', 'raha'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Wi Fi connection bohot slow hai videos loading properly nahi ho rahi',
        'words': ['Wi', 'Fi', 'connection', 'bohot', 'slow', 'hai', 'videos', 'loading', 'properly', 'nahi', 'ho', 'rahi'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Subah se rain ho rahi hai everything is totally flooded',
        'words': ['Subah', 'se', 'rain', 'ho', 'rahi', 'hai', 'everything', 'is', 'totally', 'flooded'],
        'labels': ['URD', 'URD', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Market ja raha hoon to buy some fresh groceries',
        'words': ['Market', 'ja', 'raha', 'hoon', 'to', 'buy', 'some', 'fresh', 'groceries'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Gym jana hai aaj missing workouts for 3 days straight',
        'words': ['Gym', 'jana', 'hai', 'aaj', 'missing', 'workouts', 'for', '3', 'days', 'straight'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'MIX', 'ENG', 'ENG']
    },

    # 31-40
    {
        'sentence': 'Neend nahi aa rahi watching movies all night long',
        'words': ['Neend', 'nahi', 'aa', 'rahi', 'watching', 'movies', 'all', 'night', 'long'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Car breakdown ho gayi waiting for the mechanic right now',
        'words': ['Car', 'breakdown', 'ho', 'gayi', 'waiting', 'for', 'the', 'mechanic', 'right', 'now'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Key mil nahi rahi searched every single corner of the room',
        'words': ['Key', 'mil', 'nahi', 'rahi', 'searched', 'every', 'single', 'corner', 'of', 'the', 'room'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'AC repair waala aaya tha fixed the cooling issue completely',
        'words': ['AC', 'repair', 'waala', 'aaya', 'tha', 'fixed', 'the', 'cooling', 'issue', 'completely'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Water bottle refill kar do feeling extremely dehydrated',
        'words': ['Water', 'bottle', 'refill', 'kar', 'do', 'feeling', 'extremely', 'dehydrated'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Kapde iron karne hain running late for the party',
        'words': ['Kapde', 'iron', 'karne', 'hain', 'running', 'late', 'for', 'the', 'party'],
        'labels': ['URD', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Room bohot messy hai planning a deep clean this weekend',
        'words': ['Room', 'bohot', 'messy', 'hai', 'planning', 'a', 'deep', 'clean', 'this', 'weekend'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Alarm snooze ho gaya tha woke up super late today',
        'words': ['Alarm', 'snooze', 'ho', 'gaya', 'tha', 'woke', 'up', 'super', 'late', 'today'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Breakfast skip kar diya directly having lunch today',
        'words': ['Breakfast', 'skip', 'kar', 'diya', 'directly', 'having', 'lunch', 'today'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Dinner menu kya hai I am hoping for something special',
        'words': ['Dinner', 'menu', 'kya', 'hai', 'I', 'am', 'hoping', 'for', 'something', 'special'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 41-50
    {
        'sentence': 'Mera phone discharge ho gaya tha couldn t reply on time',
        'words': ['Mera', 'phone', 'discharge', 'ho', 'gaya', 'tha', 'couldn', 't', 'reply', 'on', 'time'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Post like aur comment kar do help me boost the reach',
        'words': ['Post', 'like', 'aur', 'comment', 'kar', 'do', 'help', 'me', 'boost', 'the', 'reach'],
        'labels': ['ENG', 'ENG', 'URD', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Story update ho gayi hai go check it out right now',
        'words': ['Story', 'update', 'ho', 'gayi', 'hai', 'go', 'check', 'it', 'out', 'right', 'now'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'WhatsApp status dekha mera it was so funny',
        'words': ['WhatsApp', 'status', 'dekha', 'mera', 'it', 'was', 'so', 'funny'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Instagram algorithm is strange posts reach dropping continuously',
        'words': ['Instagram', 'algorithm', 'is', 'strange', 'posts', 'reach', 'dropping', 'continuously'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Password bhool gaya hoon need to reset it immediately',
        'words': ['Password', 'bhool', 'gaya', 'hoon', 'need', 'to', 'reset', 'it', 'immediately'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Storage full ho gayi hai deleting unnecessary photos',
        'words': ['Storage', 'full', 'ho', 'gayi', 'hai', 'deleting', 'unnecessary', 'photos'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Live stream start ho gayi join as soon as possible',
        'words': ['Live', 'stream', 'start', 'ho', 'gayi', 'join', 'as', 'soon', 'as', 'possible'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Video edit ho gayi hai ready to export and upload',
        'words': ['Video', 'edit', 'ho', 'gayi', 'hai', 'ready', 'to', 'export', 'and', 'upload'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Notification volume low tha missed your urgent message',
        'words': ['Notification', 'volume', 'low', 'tha', 'missed', 'your', 'urgent', 'message'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 51-60
    {
        'sentence': 'Mera account hack ho gaya tha luckily recovered it back',
        'words': ['Mera', 'account', 'hack', 'ho', 'gaya', 'tha', 'luckily', 'recovered', 'it', 'back'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'New update download kar lo fixed all the annoying bugs',
        'words': ['New', 'update', 'download', 'kar', 'lo', 'fixed', 'all', 'the', 'annoying', 'bugs'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Online shopping kar raha hoon huge sale is going on',
        'words': ['Online', 'shopping', 'kar', 'raha', 'hoon', 'huge', 'sale', 'is', 'going', 'on'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Payment decline ho gayi trying another credit card',
        'words': ['Payment', 'decline', 'ho', 'gayi', 'trying', 'another', 'credit', 'card'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Delivery today confirm hai track the parcel status',
        'words': ['Delivery', 'today', 'confirm', 'hai', 'track', 'the', 'parcel', 'status'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Unsubscribe kar diya newsletter spamming my inbox every hour',
        'words': ['Unsubscribe', 'kar', 'diya', 'newsletter', 'spamming', 'my', 'inbox', 'every', 'hour'],
        'labels': ['ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'App continually crash ho rahi hai reinstalling it right now',
        'words': ['App', 'continually', 'crash', 'ho', 'rahi', 'hai', 'reinstalling', 'it', 'right', 'now'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Profile picture change ki hai how is the new look',
        'words': ['Profile', 'picture', 'change', 'ki', 'hai', 'how', 'is', 'the', 'new', 'look'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Voice note sun lo explanation detailed hai usme',
        'words': ['Voice', 'note', 'sun', 'lo', 'explanation', 'detailed', 'hai', 'usme'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'URD', 'URD']
    },
    {
        'sentence': 'Group chat mute kar diya notifications were getting annoying',
        'words': ['Group', 'chat', 'mute', 'kar', 'diya', 'notifications', 'were', 'getting', 'annoying'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 61-70
    {
        'sentence': 'Plan final kar lo where are we hanging out this weekend',
        'words': ['Plan', 'final', 'kar', 'lo', 'where', 'are', 'we', 'hanging', 'out', 'this', 'weekend'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Tickets book ho gayi hain packing starts tonight',
        'words': ['Tickets', 'book', 'ho', 'gayi', 'hain', 'packing', 'starts', 'tonight'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Flight delayed hai by 3 hours waiting at the lounge',
        'words': ['Flight', 'delayed', 'hai', 'by', '3', 'hours', 'waiting', 'at', 'the', 'lounge'],
        'labels': ['ENG', 'ENG', 'URD', 'ENG', 'MIX', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Hotel reservation confirm ho gayi view looks amazing from the room',
        'words': ['Hotel', 'reservation', 'confirm', 'ho', 'gayi', 'view', 'looks', 'amazing', 'from', 'the', 'room'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Road trip par chalte hain playlist is fully ready',
        'words': ['Road', 'trip', 'par', 'chalte', 'hain', 'playlist', 'is', 'fully', 'ready'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Fuel tank full karwa lo long drive ahead',
        'words': ['Fuel', 'tank', 'full', 'karwa', 'lo', 'long', 'drive', 'ahead'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Location share kar do following the Google Maps route',
        'words': ['Location', 'share', 'kar', 'do', 'following', 'the', 'Google', 'Maps', 'route'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Bohot maza aaya trip par created unforgettable memories',
        'words': ['Bohot', 'maza', 'aaya', 'trip', 'par', 'created', 'unforgettable', 'memories'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Train arrival time kya hai reaching the station soon',
        'words': ['Train', 'arrival', 'time', 'kya', 'hai', 'reaching', 'the', 'station', 'soon'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Luggage bohot heavy hai need help carrying these bags',
        'words': ['Luggage', 'bohot', 'heavy', 'hai', 'need', 'help', 'carrying', 'these', 'bags'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 71-80
    {
        'sentence': 'Passport renew karwani hai appointment booked for next week',
        'words': ['Passport', 'renew', 'karwani', 'hai', 'appointment', 'booked', 'for', 'next', 'week'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Beach par chalte hain weather is perfect for sunset view',
        'words': ['Beach', 'par', 'chalte', 'hain', 'weather', 'is', 'perfect', 'for', 'sunset', 'view'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Northern areas ka tour plan kar rahe hain next month',
        'words': ['Northern', 'areas', 'ka', 'tour', 'plan', 'kar', 'rahe', 'hain', 'next', 'month'],
        'labels': ['ENG', 'ENG', 'URD', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': 'Resort bohot peaceful hai total relax mode on',
        'words': ['Resort', 'bohot', 'peaceful', 'hai', 'total', 'relax', 'mode', 'on'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Local street food try karte hain highly recommended by reviews',
        'words': ['Local', 'street', 'food', 'try', 'karte', 'hain', 'highly', 'recommended', 'by', 'reviews'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Driver late aaya missed the morning connection',
        'words': ['Driver', 'late', 'aaya', 'missed', 'the', 'morning', 'connection'],
        'labels': ['ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Camera charge kar lo taking tons of scenic pictures',
        'words': ['Camera', 'charge', 'kar', 'lo', 'taking', 'tons', 'of', 'scenic', 'pictures'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Souvenirs khareed liye hain for family and friends',
        'words': ['Souvenirs', 'khareed', 'liye', 'hain', 'for', 'family', 'and', 'friends'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Guide explain kar raha tha history was super interesting',
        'words': ['Guide', 'explain', 'kar', 'raha', 'tha', 'history', 'was', 'super', 'interesting'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Return journey tomorrow hai packing everything back',
        'words': ['Return', 'journey', 'tomorrow', 'hai', 'packing', 'everything', 'back'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG']
    },

    # 81-90
    {
        'sentence': 'Bohot achhi baat hai I am extremely happy for you',
        'words': ['Bohot', 'achhi', 'baat', 'hai', 'I', 'am', 'extremely', 'happy', 'for', 'you'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Mera mood off hai don t feel like talking to anyone',
        'words': ['Mera', 'mood', 'off', 'hai', 'don', 't', 'feel', 'like', 'talking', 'to', 'anyone'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Gussa mat ho it was just an accidental mistake',
        'words': ['Gussa', 'mat', 'ho', 'it', 'was', 'just', 'an', 'accidental', 'mistake'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'I am so proud of you bohot hard work kiya hai tumne',
        'words': ['I', 'am', 'so', 'proud', 'of', 'you', 'bohot', 'hard', 'work', 'kiya', 'hai', 'tumne'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Trust me main sach bol raha hoon without any exaggeration',
        'words': ['Trust', 'me', 'main', 'sach', 'bol', 'raha', 'hoon', 'without', 'any', 'exaggeration'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Missed you so much finally meeting after ages',
        'words': ['Missed', 'you', 'so', 'much', 'finally', 'meeting', 'after', 'ages'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Soch samajh kar decision lo don t rush into things',
        'words': ['Soch', 'samajh', 'kar', 'decision', 'lo', 'don', 't', 'rush', 'into', 'things'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Sab theek ho jaye ga just stay strong and patient',
        'words': ['Sab', 'theek', 'ho', 'jaye', 'ga', 'just', 'stay', 'strong', 'and', 'patient'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Surprise gift pasand aaya hope you loved it',
        'words': ['Surprise', 'gift', 'pasand', 'aaya', 'hope', 'you', 'loved', 'it'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Dil toot gaya mera expecting way better from you',
        'words': ['Dil', 'toot', 'gaya', 'mera', 'expecting', 'way', 'better', 'from', 'you'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 91-100
    {
        'sentence': 'Confusion bohot hai can you please clarify this again',
        'words': ['Confusion', 'bohot', 'hai', 'can', 'you', 'please', 'clarify', 'this', 'again'],
        'labels': ['ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Respect earned hoti hai cannot force anyone to care',
        'words': ['Respect', 'earned', 'hoti', 'hai', 'cannot', 'force', 'anyone', 'to', 'care'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Honesty is important jhooth mat bolo right now',
        'words': ['Honesty', 'is', 'important', 'jhooth', 'mat', 'bolo', 'right', 'now'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': 'Suno ek baat I need your opinion on something urgent',
        'words': ['Suno', 'ek', 'baat', 'I', 'need', 'your', 'opinion', 'on', 'something', 'urgent'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Overthinking mat karo everything will turn out fine',
        'words': ['Overthinking', 'mat', 'karo', 'everything', 'will', 'turn', 'out', 'fine'],
        'labels': ['ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Careless behaviour mat dikhao take responsibilities seriously',
        'words': ['Careless', 'behaviour', 'mat', 'dikhao', 'take', 'responsibilities', 'seriously'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Understanding issue hai we need to communicate directly',
        'words': ['Understanding', 'issue', 'hai', 'we', 'need', 'to', 'communicate', 'directly'],
        'labels': ['ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Support ke liye thanks could not do this without you',
        'words': ['Support', 'ke', 'liye', 'thanks', 'could', 'not', 'do', 'this', 'without', 'you'],
        'labels': ['ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Jealous feel kar raha hai seeing all those holiday posts',
        'words': ['Jealous', 'feel', 'kar', 'raha', 'hai', 'seeing', 'all', 'those', 'holiday', 'posts'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Patience rakho thoda good things take time always',
        'words': ['Patience', 'rakho', 'thoda', 'good', 'things', 'take', 'time', 'always'],
        'labels': ['ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 101-110
    {
        'sentence': 'Junk food kam khao focus on healthy diet from now',
        'words': ['Junk', 'food', 'kam', 'khao', 'focus', 'on', 'healthy', 'diet', 'from', 'now'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Doctor ne medicine prescribe ki hai take it twice daily',
        'words': ['Doctor', 'ne', 'medicine', 'prescribe', 'ki', 'hai', 'take', 'it', 'twice', 'daily'],
        'labels': ['ENG', 'URD', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Fever ho raha hai resting at home whole day',
        'words': ['Fever', 'ho', 'raha', 'hai', 'resting', 'at', 'home', 'whole', 'day'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Headache bohot severe hai taking a quick nap',
        'words': ['Headache', 'bohot', 'severe', 'hai', 'taking', 'a', 'quick', 'nap'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Water intake increase karo stay hydrated all day',
        'words': ['Water', 'intake', 'increase', 'karo', 'stay', 'hydrated', 'all', 'day'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Biryani order kar lo best choice for Sunday lunch',
        'words': ['Biryani', 'order', 'kar', 'lo', 'best', 'choice', 'for', 'Sunday', 'lunch'],
        'labels': ['URD', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Spicy food pasand hai adding extra chili flakes',
        'words': ['Spicy', 'food', 'pasand', 'hai', 'adding', 'extra', 'chili', 'flakes'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Calories count kar raha hoon strictly on diet right now',
        'words': ['Calories', 'count', 'kar', 'raha', 'hoon', 'strictly', 'on', 'diet', 'right', 'now'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Weight lose karna hai running 5 km every single morning',
        'words': ['Weight', 'lose', 'karna', 'hai', 'running', '5', 'km', 'every', 'single', 'morning'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'MIX', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Protein intake complete nahi ho raha buying whey supplement',
        'words': ['Protein', 'intake', 'complete', 'nahi', 'ho', 'raha', 'buying', 'whey', 'supplement'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },

    # 111-120
    {
        'sentence': 'Tea spill ho gayi cleaning the carpet right now',
        'words': ['Tea', 'spill', 'ho', 'gayi', 'cleaning', 'the', 'carpet', 'right', 'now'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Fresh juice peena hai boost immunity naturally',
        'words': ['Fresh', 'juice', 'peena', 'hai', 'boost', 'immunity', 'naturally'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Sugar completely stop kar di hai for 1 full month',
        'words': ['Sugar', 'completely', 'stop', 'kar', 'di', 'hai', 'for', '1', 'full', 'month'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'MIX', 'ENG', 'ENG']
    },
    {
        'sentence': 'Back pain ho raha hai sitting posture needs improvement',
        'words': ['Back', 'pain', 'ho', 'raha', 'hai', 'sitting', 'posture', 'needs', 'improvement'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Dentist appointment setup hai for root canal checkup',
        'words': ['Dentist', 'appointment', 'setup', 'hai', 'for', 'root', 'canal', 'checkup'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Sleep schedule ruined hai waking up at midnight',
        'words': ['Sleep', 'schedule', 'ruined', 'hai', 'waking', 'up', 'at', 'midnight'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Energy feel nahi ho rahi feeling low on stamina',
        'words': ['Energy', 'feel', 'nahi', 'ho', 'rahi', 'feeling', 'low', 'on', 'stamina'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Fruit salad taiyar hai healthy snacking options',
        'words': ['Fruit', 'salad', 'taiyar', 'hai', 'healthy', 'snacking', 'options'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Cold coffee amazing hai perfectly blended ice',
        'words': ['Cold', 'coffee', 'amazing', 'hai', 'perfectly', 'blended', 'ice'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Allergy reaction ho gaya taking anti histamine tablet',
        'words': ['Allergy', 'reaction', 'ho', 'gaya', 'taking', 'anti', 'histamine', 'tablet'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 121-130
    {
        'sentence': 'Movie tickets reserve ho gayi hain show starts at 8 PM',
        'words': ['Movie', 'tickets', 'reserve', 'ho', 'gayi', 'hain', 'show', 'starts', 'at', '8', 'PM'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'MIX', 'ENG']
    },
    {
        'sentence': 'New episode drop ho gaya watching it right away',
        'words': ['New', 'episode', 'drop', 'ho', 'gaya', 'watching', 'it', 'right', 'away'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Outfit selection confusion hai which color suits best',
        'words': ['Outfit', 'selection', 'confusion', 'hai', 'which', 'color', 'suits', 'best'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Brand new shoes buy kiye super comfortable fitting',
        'words': ['Brand', 'new', 'shoes', 'buy', 'kiye', 'super', 'comfortable', 'fitting'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Discount code apply kar do get extra 20 percent off',
        'words': ['Discount', 'code', 'apply', 'kar', 'do', 'get', 'extra', '20', 'percent', 'off'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'MIX', 'ENG', 'ENG']
    },
    {
        'sentence': 'Budget exceed ho gaya need to control shopping habits',
        'words': ['Budget', 'exceed', 'ho', 'gaya', 'need', 'to', 'control', 'shopping', 'habits'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Review read kar lo before purchasing expensive gadget',
        'words': ['Review', 'read', 'kar', 'lo', 'before', 'purchasing', 'expensive', 'gadget'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Concert performance climax par tha crowd went completely wild',
        'words': ['Concert', 'performance', 'climax', 'par', 'tha', 'crowd', 'went', 'completely', 'wild'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Season finale ruined everything worst ending ever scripted',
        'words': ['Season', 'finale', 'ruined', 'everything', 'worst', 'ending', 'ever', 'scripted'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Online reviews fake lag rahe hain don t trust blindly',
        'words': ['Online', 'reviews', 'fake', 'lag', 'rahe', 'hain', 'don', 't', 'trust', 'blindly'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 131-140
    {
        'sentence': 'Quality drop ho gayi hai returning this item back',
        'words': ['Quality', 'drop', 'ho', 'gayi', 'hai', 'returning', 'this', 'item', 'back'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Thrift store gems mil gaye awesome vintage jacket',
        'words': ['Thrift', 'store', 'gems', 'mil', 'gaye', 'awesome', 'vintage', 'jacket'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Watch collection check karo added a classy time piece',
        'words': ['Watch', 'collection', 'check', 'karo', 'added', 'a', 'classy', 'time', 'piece'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Sales representative helpful tha solved all my queries fast',
        'words': ['Sales', 'representative', 'helpful', 'tha', 'solved', 'all', 'my', 'queries', 'fast'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Mall mein crowding bohot hai leaving immediately',
        'words': ['Mall', 'mein', 'crowding', 'bohot', 'hai', 'leaving', 'immediately'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': 'Song loop par chal raha hai addictive lyrics melody',
        'words': ['Song', 'loop', 'par', 'chal', 'raha', 'hai', 'addictive', 'lyrics', 'melody'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Trailer launching today waiting eagerly for the premiere',
        'words': ['Trailer', 'launching', 'today', 'waiting', 'eagerly', 'for', 'the', 'premiere'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Series binge watch kar li finished in 1 sitting',
        'words': ['Series', 'binge', 'watch', 'kar', 'li', 'finished', 'in', '1', 'sitting'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'MIX', 'ENG']
    },
    {
        'sentence': 'Fitting loose hai need to exchange for small size',
        'words': ['Fitting', 'loose', 'hai', 'need', 'to', 'exchange', 'for', 'small', 'size'],
        'labels': ['ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Payment receipt save kar lo required for warranty claim',
        'words': ['Payment', 'receipt', 'save', 'kar', 'lo', 'required', 'for', 'warranty', 'claim'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # 141-152
    {
        'sentence': 'Life bohot fast move ho rahi hai time flies quickly',
        'words': ['Life', 'bohot', 'fast', 'move', 'ho', 'rahi', 'hai', 'time', 'flies', 'quickly'],
        'labels': ['ENG', 'URD', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Coincidence dekho meeting you here unexpectedly',
        'words': ['Coincidence', 'dekho', 'meeting', 'you', 'here', 'unexpectedly'],
        'labels': ['ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Situation handle ho gayi no need to panic anymore',
        'words': ['Situation', 'handle', 'ho', 'gayi', 'no', 'need', 'to', 'panic', 'anymore'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Experience matter karta hai learning from daily mistakes',
        'words': ['Experience', 'matter', 'karta', 'hai', 'learning', 'from', 'daily', 'mistakes'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Opportunity miss mat karo grab it immediately',
        'words': ['Opportunity', 'miss', 'mat', 'karo', 'grab', 'it', 'immediately'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Rule strictly follow karo avoid paying heavy fines',
        'words': ['Rule', 'strictly', 'follow', 'karo', 'avoid', 'paying', 'heavy', 'fines'],
        'labels': ['ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Luck favor kar raha hai everything is falling in place',
        'words': ['Luck', 'favor', 'kar', 'raha', 'hai', 'everything', 'is', 'falling', 'in', 'place'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Focus distract ho raha hai closing all browser windows',
        'words': ['Focus', 'distract', 'ho', 'raha', 'hai', 'closing', 'all', 'browser', 'windows'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'System overload ho gaya rebooting hardware system',
        'words': ['System', 'overload', 'ho', 'gaya', 'rebooting', 'hardware', 'system'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Result announce ho gaya cleared all exams successfully',
        'words': ['Result', 'announce', 'ho', 'gaya', 'cleared', 'all', 'exams', 'successfully'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Idea bohot brilliant hai let us implement this strategy',
        'words': ['Idea', 'bohot', 'brilliant', 'hai', 'let', 'us', 'implement', 'this', 'strategy'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Inspiration mil gayi starting a new project today',
        'words': ['Inspiration', 'mil', 'gayi', 'starting', 'a', 'new', 'project', 'today'],
        'labels': ['ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    }
]

# 4. Convert to flat CSV format
rows = []
for entry in data:
    for word, label in zip(entry['words'], entry['labels']):
        rows.append({
            'sentence': entry['sentence'],
            'word': word,
            'label': label
        })

df = pd.DataFrame(rows)

# 5. Save to Google Drive AND current Colab folder
drive_path = os.path.join(drive_folder, 'dataset.csv')
df.to_csv(drive_path, index=False, encoding='utf-8')
df.to_csv('dataset.csv', index=False, encoding='utf-8')

print(f'✅ Dataset created: {len(df)} word entries')
print(f'✅ Unique Sentences: {df.sentence.nunique()}')
print(f'💾 Saved permanently to Drive: {drive_path}')
# Out:
# ✅ Dataset created: 1393 word entries
# ✅ Unique Sentences: 152
# 💾 Saved permanently to Drive: /content/drive/MyDrive/CodeSaviours_Project2/dataset.csv
