# %% [markdown]
# <a href="https://colab.research.google.com/github/Hania-Emaan/code-switching-codesaviours-si26-Hania-Emaan/blob/main/SI26_Week6_Hania_Emaan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Each entry has: the full sentence + word-by-word labels
# Label each word as: URD (Urdu/Roman Urdu), ENG (English), or MIX
data = [
    # --- Standard Code-Switched Sentences ---
    {
        'sentence': 'Aaj ka din bohot busy tha',
        'words': ['Aaj', 'ka', 'din', 'bohot', 'busy', 'tha'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'ENG', 'URD']
    },
    {
        'sentence': 'Yaar seriously I can not even right now',
        'words': ['Yaar', 'seriously', 'I', 'can', 'not', 'even', 'right', 'now'],
        'labels': ['URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Bhai kal mera presentation hai',
        'words': ['Bhai', 'kal', 'mera', 'presentation', 'hai'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'URD']
    },
    {
        'sentence': 'Khana kha liya I was literally waiting for you',
        'words': ['Khana', 'kha', 'liya', 'I', 'was', 'literally', 'waiting', 'for', 'you'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Mujhe samajh nahi aa raha why this code is giving error',
        'words': ['Mujhe', 'samajh', 'nahi', 'aa', 'raha', 'why', 'this', 'code', 'is', 'giving', 'error'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Mera assignment complete ho gaya hai I will submit it tomorrow',
        'words': ['Mera', 'assignment', 'complete', 'ho', 'gaya', 'hai', 'I', 'will', 'submit', 'it', 'tomorrow'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Kal subah early morning class hai',
        'words': ['Kal', 'subah', 'early', 'morning', 'class', 'hai'],
        'labels': ['URD', 'URD', 'ENG', 'ENG', 'ENG', 'URD']
    },
    {
        'sentence': 'Project deadline is approaching fast aur humne start bhi nahi kiya',
        'words': ['Project', 'deadline', 'is', 'approaching', 'fast', 'aur', 'humne', 'start', 'bhi', 'nahi', 'kiya'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Professor is very strict late submission accept nahi karenge',
        'words': ['Professor', 'is', 'very', 'strict', 'late', 'submission', 'accept', 'nahi', 'karenge'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'URD']
    },
    {
        'sentence': 'Group project mein koi kaam nahi kar raha',
        'words': ['Group', 'project', 'mein', 'koi', 'kaam', 'nahi', 'kar', 'raha'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Mera laptop crash ho gaya lost all my unsaved files',
        'words': ['Mera', 'laptop', 'crash', 'ho', 'gaya', 'lost', 'all', 'my', 'unsaved', 'files'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Library mein bohot noise hai I cannot concentrate here',
        'words': ['Library', 'mein', 'bohot', 'noise', 'hai', 'I', 'cannot', 'concentrate', 'here'],
        'labels': ['ENG', 'URD', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Bhai notes share kar do I missed today lecture',
        'words': ['Bhai', 'notes', 'share', 'kar', 'do', 'I', 'missed', 'today', 'lecture'],
        'labels': ['URD', 'ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Exam pass ho gaya hard work finally paid off',
        'words': ['Exam', 'pass', 'ho', 'gaya', 'hard', 'work', 'finally', 'paid', 'off'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Office meeting was so boring poora time neend aati rahi',
        'words': ['Office', 'meeting', 'was', 'so', 'boring', 'poora', 'time', 'neend', 'aati', 'rahi'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'I need a long vacation bohot burnout feel ho raha hai',
        'words': ['I', 'need', 'a', 'long', 'vacation', 'bohot', 'burnout', 'feel', 'ho', 'raha', 'hai'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Salary credit ho gayi time to pay all pending bills',
        'words': ['Salary', 'credit', 'ho', 'gayi', 'time', 'to', 'pay', 'all', 'pending', 'bills'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Resume update kar liya hai now applying for remote jobs',
        'words': ['Resume', 'update', 'kar', 'liya', 'hai', 'now', 'applying', 'for', 'remote', 'jobs'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Interview schedule ho gaya hai for next Monday',
        'words': ['Interview', 'schedule', 'ho', 'gaya', 'hai', 'for', 'next', 'Monday'],
        'labels': ['ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Manager ne feedback diya hai need to make quick revisions',
        'words': ['Manager', 'ne', 'feedback', 'diya', 'hai', 'need', 'to', 'make', 'quick', 'revisions'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Chai peene chalte hain I really need a short break',
        'words': ['Chai', 'peene', 'chalte', 'hain', 'I', 'really', 'need', 'a', 'short', 'break'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Weather is so nice today baahir ghoomne chalte hain',
        'words': ['Weather', 'is', 'so', 'nice', 'today', 'baahir', 'ghoomne', 'chalte', 'hain'],
        'labels': ['ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Bohot zor ki bhook lag rahi hai let us order food',
        'words': ['Bohot', 'zor', 'ki', 'bhook', 'lag', 'rahi', 'hai', 'let', 'us', 'order', 'food'],
        'labels': ['URD', 'URD', 'URD', 'URD', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Traffic bohot heavy tha I got stuck for two hours',
        'words': ['Traffic', 'bohot', 'heavy', 'tha', 'I', 'got', 'stuck', 'for', 'two', 'hours'],
        'labels': ['ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Ghar pohench kar call karta hoon currently driving',
        'words': ['Ghar', 'pohench', 'kar', 'call', 'karta', 'hoon', 'currently', 'driving'],
        'labels': ['URD', 'URD', 'URD', 'ENG', 'URD', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': 'Electricity chali gayi hai generator bhi work nahi kar raha',
        'words': ['Electricity', 'chali', 'gayi', 'hai', 'generator', 'bhi', 'work', 'nahi', 'kar', 'raha'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Wi-Fi connection bohot slow hai videos loading properly nahi ho rahi',
        'words': ['Wi-Fi', 'connection', 'bohot', 'slow', 'hai', 'videos', 'loading', 'properly', 'nahi', 'ho', 'rahi'],
        'labels': ['ENG', 'ENG', 'URD', 'ENG', 'URD', 'ENG', 'ENG', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Subah se rain ho rahi hai everything is totally flooded',
        'words': ['Subah', 'se', 'rain', 'ho', 'rahi', 'hai', 'everything', 'is', 'totally', 'flooded'],
        'labels': ['URD', 'URD', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Market ja raha hoon to buy some fresh groceries',
        'words': ['Market', 'ja', 'raha', 'hoon', 'to', 'buy', 'some', 'fresh', 'groceries'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'Gym jana hai aaj missing workouts for three days straight',
        'words': ['Gym', 'jana', 'hai', 'aaj', 'missing', 'workouts', 'for', 'three', 'days', 'straight'],
        'labels': ['ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG', 'ENG']
    },

    # --- Realistic Intra-Word Code-Switching & Hybrid MIX Sentences ---
    {
        'sentence': 'Sari postain check kar lo bohot updates aayi hain',
        'words': ['Sari', 'postain', 'check', 'kar', 'lo', 'bohot', 'updates', 'aayi', 'hain'],
        'labels': ['URD', 'MIX', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'URD', 'URD']
    },
    {
        'sentence': 'In picain ko drive par upload kar do',
        'words': ['In', 'picain', 'ko', 'drive', 'par', 'upload', 'kar', 'do'],
        'labels': ['URD', 'MIX', 'URD', 'ENG', 'URD', 'ENG', 'URD', 'URD']
    },
    {
        'sentence': 'Bhai uski callon ko ignore kar rahe ho why',
        'words': ['Bhai', 'uski', 'callon', 'ko', 'ignore', 'kar', 'rahe', 'ho', 'why'],
        'labels': ['URD', 'URD', 'MIX', 'URD', 'ENG', 'URD', 'URD', 'URD', 'ENG']
    },
    {
        'sentence': 'Sare commenton ka reply kar diya hai',
        'words': ['Sare', 'commenton', 'ka', 'reply', 'kar', 'diya', 'hai'],
        'labels': ['URD', 'MIX', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Mera account checko status update ho gaya hai',
        'words': ['Mera', 'account', 'checko', 'status', 'update', 'ho', 'gaya', 'hai'],
        'labels': ['URD', 'ENG', 'MIX', 'ENG', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'In linkon par click mat karna spam lag raha hai',
        'words': ['In', 'linkon', 'par', 'click', 'mat', 'karna', 'spam', 'lag', 'raha', 'hai'],
        'labels': ['URD', 'MIX', 'URD', 'ENG', 'URD', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Saari storyain delete kar di hain usne',
        'words': ['Saari', 'storyain', 'delete', 'kar', 'di', 'hain', 'usne'],
        'labels': ['URD', 'MIX', 'ENG', 'URD', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Ziyada actingain mat dikhao simple reply karo',
        'words': ['Ziyada', 'actingain', 'mat', 'dikhao', 'simple', 'reply', 'karo'],
        'labels': ['URD', 'MIX', 'URD', 'URD', 'ENG', 'ENG', 'URD']
    },
    {
        'sentence': 'In filmon ko download kar ke dekho',
        'words': ['In', 'filmon', 'ko', 'download', 'kar', 'ke', 'dekho'],
        'labels': ['URD', 'MIX', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Bhai message reado urgent response chahiye',
        'words': ['Bhai', 'message', 'reado', 'urgent', 'response', 'chahiye'],
        'labels': ['URD', 'ENG', 'MIX', 'ENG', 'ENG', 'URD']
    },
    {
        'sentence': 'Sare folderon ko safe place par move karo',
        'words': ['Sare', 'folderon', 'ko', 'safe', 'place', 'par', 'move', 'karo'],
        'labels': ['URD', 'MIX', 'URD', 'ENG', 'ENG', 'URD', 'ENG', 'URD']
    },
    {
        'sentence': 'In reporton ko manager ko send karna hai',
        'words': ['In', 'reporton', 'ko', 'manager', 'ko', 'send', 'karna', 'hai'],
        'labels': ['URD', 'MIX', 'URD', 'ENG', 'URD', 'ENG', 'URD', 'URD']
    },
    {
        'sentence': 'Offerain check kar lo discount chal raha hai',
        'words': ['Offerain', 'check', 'kar', 'lo', 'discount', 'chal', 'raha', 'hai'],
        'labels': ['MIX', 'ENG', 'URD', 'URD', 'ENG', 'URD', 'URD', 'URD']
    },
    {
        'sentence': 'Sari detailain website par available hain',
        'words': ['Sari', 'detailain', 'website', 'par', 'available', 'hain'],
        'labels': ['URD', 'MIX', 'ENG', 'URD', 'ENG', 'URD']
    },
    {
        'sentence': 'Instagram ki settingain change kar do',
        'words': ['Instagram', 'ki', 'settingain', 'change', 'kar', 'do'],
        'labels': ['ENG', 'URD', 'MIX', 'ENG', 'URD', 'URD']
    },
    {
        'sentence': 'Groupain join kar lo for latest updates',
        'words': ['Groupain', 'join', 'kar', 'lo', 'for', 'latest', 'updates'],
        'labels': ['MIX', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': 'In issueain ko solve karo right now',
        'words': ['In', 'issueain', 'ko', 'solve', 'karo', 'right', 'now'],
        'labels': ['URD', 'MIX', 'URD', 'ENG', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': 'Sari requirementain read karo carefully',
        'words': ['Sari', 'requirementain', 'read', 'karo', 'carefully'],
        'labels': ['URD', 'MIX', 'ENG', 'URD', 'ENG']
    },
    {
        'sentence': 'Resultain check kar lo on student portal',
        'words': ['Resultain', 'check', 'kar', 'lo', 'on', 'student', 'portal'],
        'labels': ['MIX', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG']
    },

    # --- Numeric & Symbol MIX Patterns ---
    {
        'sentence': '1st position aayi hai I am super excited',
        'words': ['1st', 'position', 'aayi', 'hai', 'I', 'am', 'super', 'excited'],
        'labels': ['MIX', 'ENG', 'URD', 'URD', 'ENG', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': '2nd time call kar raha hoon reply back',
        'words': ['2nd', 'time', 'call', 'kar', 'raha', 'hoon', 'reply', 'back'],
        'labels': ['MIX', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': '3rd chapter start kar diya hai today',
        'words': ['3rd', 'chapter', 'start', 'kar', 'diya', 'hai', 'today'],
        'labels': ['MIX', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG']
    },
    {
        'sentence': '100% genuine condition hai buy without hesitation',
        'words': ['100%', 'genuine', 'condition', 'hai', 'buy', 'without', 'hesitation'],
        'labels': ['MIX', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'ENG']
    },
    {
        'sentence': '50-50 chance lag raha hai for passing',
        'words': ['50-50', 'chance', 'lag', 'raha', 'hai', 'for', 'passing'],
        'labels': ['MIX', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': '24/7 service available hai contact anytime',
        'words': ['24/7', 'service', 'available', 'hai', 'contact', 'anytime'],
        'labels': ['MIX', 'ENG', 'ENG', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': '10k followers complete ho gaye hain on Instagram',
        'words': ['10k', 'followers', 'complete', 'ho', 'gaye', 'hain', 'on', 'Instagram'],
        'labels': ['MIX', 'ENG', 'ENG', 'URD', 'URD', 'URD', 'ENG', 'ENG']
    },
    {
        'sentence': '5th attempt mein clear hua hai test',
        'words': ['5th', 'attempt', 'mein', 'clear', 'hua', 'hai', 'test'],
        'labels': ['MIX', 'ENG', 'URD', 'ENG', 'URD', 'URD', 'ENG']
    },
    {
        'sentence': '99% server uptime hai performance solid hai',
        'words': ['99%', 'server', 'uptime', 'hai', 'performance', 'solid', 'hai'],
        'labels': ['MIX', 'ENG', 'ENG', 'URD', 'ENG', 'ENG', 'URD']
    }
]

# Convert to flat CSV format
rows = []
for entry in data:
    for word, label in zip(entry['words'], entry['labels']):
        rows.append({
            'sentence': entry['sentence'],
            'word': word,
            'label': label
        })

df = pd.DataFrame(rows)
df.to_csv('dataset.csv', index=False, encoding='utf-8')

print(f'Dataset created: {len(df)} word entries')
print(f'Sentences: {df.sentence.nunique()}')
print(f'Label distribution:')
print(df.label.value_counts())
# Out:
# Dataset created: 483 word entries
# Sentences: 58
# Label distribution:
# label
# ENG    243
# URD    212
# MIX     28
# Name: count, dtype: int64
